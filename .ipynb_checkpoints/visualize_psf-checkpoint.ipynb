# %%
import sys
sys.path.append('../')

import numpy as np
from matplotlib import pyplot

# %%
# %ls -l
# Out:
# total 1056
# -rwxr-xr-x@ 1 kohei  staff    1248 Jan 29 00:26 extract.py*
# drwxr-xr-x  2 kohei  staff      64 Jan 29 01:26 fig/
# -rw-r--r--  1 kohei  staff  116120 Jan 29 00:27 imagelist.npy
# -rwxr-xr-x@ 1 kohei  staff    1412 Jan 28 01:17 knownStar.py*
# -rw-r--r--  1 kohei  staff   10152 Jan 29 00:27 positionlist.npy
# -rw-r--r--  1 kohei  staff    8720 Jan 29 01:25 positionlist2.npy
# -rwxr-xr-x@ 1 kohei  staff    1303 Jan 29 00:30 psfShape.py*
# -rw-r--r--  1 kohei  staff    5960 Jan 29 01:25 psfcoeff.npy
# -rwxr-xr-x@ 1 kohei  staff    1206 Jan 28 01:17 spline.py*
# -rwxr-xr-x@ 1 kohei  staff    1027 Jan 28 01:17 starCenter.py*
# -rwxr-xr-x@ 1 kohei  staff     362 Jan 28 01:17 testspec.txt*
# -rw-r--r--  1 kohei  staff  363936 Jan 29 01:25 visualize_psf.ipynb

# %%
psf_coeff = np.load('psfcoeff.npy')

# %%
psf_coeff
# Out:
# array([[-6.93794884e+01,  1.02337236e+02,  4.94773979e+01,
#         -7.89287504e+01,  1.05828429e+02,  4.81713250e+01,
#         -6.72650983e+01,  1.02481403e+02,  4.94188680e+01,
#         -1.29980157e+02,  1.24356588e+02,  1.53512933e+01,
#         -1.44574033e+02,  1.27706073e+02, -8.76226788e+00,
#         -1.18035488e+02,  1.19357133e+02,  1.14450800e+01,
#         -7.57193022e+01,  1.05642278e+02,  4.61549526e+01,
#         -7.97419264e+01,  1.10629020e+02,  4.21666032e+01,
#         -7.62973568e+01,  1.07155967e+02,  4.34797385e+01],
#        [ 8.82205311e+01,  3.32875003e+01,  4.94429419e+01,
#          9.01344039e+01,  3.22847040e+01,  4.96878472e+01,
#          1.04691008e+02,  2.81103548e+01,  5.82423500e+01,
#          3.01374098e+02, -3.38659982e+01,  1.75015462e+02,
#          4.33668228e+02, -7.63135252e+01,  2.81752552e+02,
#          2.71784941e+02, -2.54332975e+01,  1.79352630e+02,
#          1.17518347e+02,  2.37650514e+01,  6.76074363e+01,
#          8.86763330e+01,  3.06861519e+01,  5.24409609e+01,
#          9.14248327e+01,  3.08866415e+01,  5.36054404e+01],
#        [ 7.50024915e+01,  5.33759149e+01,  6.34978250e+01,
#          1.41392608e+02,  3.56704801e+01,  9.36325580e+01,
#         -8.15844273e-01,  7.65665749e+01,  3.40700702e+01,
#         -5.49132030e+02,  2.29555402e+02, -1.49927163e+02,
#         -7.47914470e+02,  2.66878501e+02, -1.30599449e+02,
#         -1.41229721e+02,  8.85557905e+01,  1.05135674e+02,
#          3.94518171e+01,  5.65085660e+01,  8.16056798e+01,
#          9.49571073e+01,  4.91337444e+01,  7.41249568e+01,
#          5.34839206e+01,  5.82280342e+01,  6.03651110e+01],
#          2.70177562e+02, -1.34001158e+00,  1.41591012e+02,
#          9.26197283e+01,  4.21909841e+01,  6.53124499e+01,
#          3.27608347e+01,  5.37772292e+01,  5.11175595e+01,
#         -4.73919506e+01,  7.48638204e+01,  1.48418597e+01,
#          2.19483163e+01,  5.44964581e+01,  4.84872701e+01],
#        [ 2.35253987e+01,  5.92943285e+01,  3.83175230e+01,
#          1.65198387e+01,  6.14598451e+01,  3.20005320e+01,
#         -6.34423689e-01,  6.83986654e+01,  2.56621476e+01,
#          2.63195234e+01,  5.20719573e+01,  2.99084547e+01,
#         -2.03715785e+01,  6.62305855e+01,  1.10015884e+01,
#          1.00169008e+02,  4.30532414e+01,  5.53807595e+01,
#          1.00811425e+02,  4.09229749e+01,  5.61516280e+01,
#          1.87357477e+02,  2.08006824e+01,  9.24384569e+01,
#          1.03344044e+02,  3.78490062e+01,  6.37963485e+01],
#        [ 6.19183608e+01,  4.66088304e+01,  5.36326222e+01,
#          6.92340510e+01,  4.42501734e+01,  6.33229123e+01,
#          1.10217146e+02,  2.95063097e+01,  8.18396586e+01,
#          1.06895037e+02,  3.44130941e+01,  1.04552439e+02,
#          1.26614506e+02,  2.80323403e+01,  1.19204333e+02,
#         -8.62960251e+00,  6.18042189e+01,  4.65969337e+01,
#         -8.63487896e+00,  6.30514006e+01,  4.08579815e+01,
#         -1.14980003e+02,  9.30071823e+01, -1.50280268e+01,
#         -5.58163654e+01,  7.95643712e+01,  1.76987455e+01],
#        [-2.77996646e+02,  1.98309055e+02, -5.66789802e+02,
#         -1.25634608e+03,  6.13261118e+02, -2.19002454e+03,
#          2.38172531e+03, -1.08248315e+03,  5.47531216e+03,
#          1.37415238e+03, -5.63552234e+02,  2.59846096e+03,
#          5.68612515e+02, -2.02404877e+02,  1.04032776e+03,
#         -7.65373604e+03,  3.44125803e+03, -1.37158260e+04,
#         -7.60216328e+03,  3.40419965e+03, -1.34940636e+04,
#         -8.67723328e+03,  3.97502480e+03, -1.63263920e+04,
#         -7.39216551e+03,  3.39380094e+03, -1.40823961e+04]])

# %%
pyplot.plot(psf_coeff)
pyplot.show()

# %%
from estimation.psf import PSFEstimationModelFactory

# %%
pixels = 9

section_count_of_x = psf_coeff.shape[0]
section_count_of_y = psf_coeff.shape[1]

section_size_of_x = pixels / section_count_of_x
section_size_of_y = pixels / section_count_of_y

# %%
half_pixels = int(pixels / 2)

# %%
psf_model = PSFEstimationModelFactory.create_spline_model(
        section_size_of_x, section_count_of_x, section_size_of_y, section_count_of_y
)

# %%
result_array = np.zeros((pixels, pixels), dtype=int)
for x in range(-half_pixels, half_pixels + 1):
    for y in range(-half_pixels, half_pixels + 1):
        result_array[x + half_pixels, y + half_pixels] = psf_model.model_function(x, y, psf_coeff)

# %%
pyplot.plot(result_array)
pyplot.show()

# %%
result_array
# Out:
# array([[  432,   452,   453,   449,   450,   454,   449,   457,   440],
#        [  429,   448,   456,   423,   436,   457,   453,   452,   427],
#        [  433,   537,   815,   138,  -331,   501,   512,   456,   564],
#        [  414,   887,  5189,  7314,  1227,  1376,   912,   456,   487],
#        [  405,  1074, 11485, 29217, 19004,  5528,  1354,   471,   459],
#        [  407,   585,  6078, 20079, 17276,  4842,   932,   468,   301],
#        [  426,   450,  1040,  3157,  3141,  1220,   525,   462,   308],
#        [  427,   452,   470,   528,   537,   480,   457,   453,   255],
#        [  429,   459,   457,   452,   455,   457,   449,   458,   269]])

# %%
result_array.sum()
# Out:
# 168542

# %%
pyplot.plot(np.linspace(-4,4,101),psf_model.model_function(np.linspace(-4,4,101), 0, data))
pyplot.plot(np.linspace(-4,4,9),psf_model.model_function(np.linspace(-4,4,9), 0, data), 'ro')
pyplot.plot(np.linspace(-4,4,9),psf_model.model_function(np.linspace(-4,4,9), 0, ps), c='r', ls='-')
pyplot.axhline(y=0, c='k', lw=1, ls='dashed')
pyplot.grid()
pyplot.xlabel(r'$x$ pixel')
pyplot.ylabel(r'PFS')
pyplot.title(r'slice at $y=0$')
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-4d8485cbc9aa> in <module>
# ----> 1 pyplot.plot(np.linspace(-4,4,101),psf_model.model_function(np.linspace(-4,4,101), 0, data))
#       2 pyplot.plot(np.linspace(-4,4,9),psf_model.model_function(np.linspace(-4,4,9), 0, data), 'ro')
#       3 pyplot.plot(np.linspace(-4,4,9),psf_model.model_function(np.linspace(-4,4,9), 0, data), c='r', ls='-')
#       4 pyplot.axhline(y=0, c='k', lw=1, ls='dashed')
#       5 pyplot.grid()
#
# NameError: name 'data' is not defined

# %%
y=2
pyplot.plot(np.linspace(-4,4,101),psf_model.model_function(np.linspace(-4,4,101), y, data))
pyplot.plot(np.linspace(-4,4,9),psf_model.model_function(np.linspace(-4,4,9), y, data), 'ro')
pyplot.plot(np.linspace(-4,4,9),psf_model.model_function(np.linspace(-4,4,9), y, data), c='r', ls='-')
pyplot.axhline(y=0, c='k', lw=1, ls='dashed')
pyplot.grid()
pyplot.xlabel(r'$x$ pixel')
pyplot.ylabel(r'PFS')
pyplot.title(r'slice at $y=%.1lf$'% (y))
pyplot.show()

# %%
y=3
pyplot.plot(np.linspace(-4,4,101),psf_model.model_function(np.linspace(-4,4,101), y, data))
pyplot.plot(np.linspace(-4,4,9),psf_model.model_function(np.linspace(-4,4,9), y, data), 'ro')
pyplot.plot(np.linspace(-4,4,9),psf_model.model_function(np.linspace(-4,4,9), y, data), c='r', ls='-')
pyplot.axhline(y=0, c='k', lw=1, ls='dashed')
pyplot.grid()
pyplot.xlabel(r'$x$ pixel')
pyplot.ylabel(r'PFS')
pyplot.title(r'slice at $y=%.1lf$'% (y))
pyplot.show()

# %%
array_y = np.linspace(-4,4,9)

for i, y in enumerate(array_y):
    psf_continuous = psf_model.model_function(np.linspace(-4,4,101), y, data)
    max_psf_at_slice_y = np.max( psf_continuous )
    min_psf_at_slice_y = np.min( psf_continuous )
    
    pyplot.plot(np.linspace(-4,4,101),psf_model.model_function(np.linspace(-4,4,101), y, data))
    pyplot.plot(np.linspace(-4,4,9),psf_model.model_function(np.linspace(-4,4,9), y, data), 'ro')
    pyplot.plot(np.linspace(-4,4,9),psf_model.model_function(np.linspace(-4,4,9), y, data), c='r', ls='-')
    pyplot.axhline(y=0, c='k', lw=1, ls='dashed')
    pyplot.grid()
    
    pyplot.ylim([-max_psf_at_slice_y*0.1, max_psf_at_slice_y*1.1])
    pyplot.xlabel(r'$x$ pixel')
    pyplot.ylabel(r'PFS')
    pyplot.title(r'slice at $y=%.1lf$'% (y))
    pyplot.savefig('fig/psf_slice_%02d_y%+03d.png' % (i,1000*y))
    pyplot.show()

# %%
# !convert fig/*png fig/movie.gif

# %%
# !convert -delay 100 fig/*png fig/movie100.gif
